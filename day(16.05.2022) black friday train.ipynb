# %%
import pandas as pd
file=pd.read_csv("C:/Users/deepika sakthivel/Downloads/black_friday_train.csv")
df=pd.DataFrame(file)
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.shape
# Out:
# (550068, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
#  12  Unnamed: 12                 0 non-null       float64
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase', 'Unnamed: 12',
#        'Purchase.1'],
#       dtype='object')

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase  Unnamed: 12  \
# count       376430.000000       166821.000000  550068.000000          0.0
# mean             9.842329           12.668243    9263.968713          NaN
# std              5.086590            4.125338    5023.065394          NaN
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# Unnamed: 12                   550068
# Purchase.1                    535499
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 550063    False
# 550064    False
# 550065    False
# 550066    False
# 550067    False
# Length: 550068, dtype: bool

# %%
df.drop_duplicates()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.drop_duplicates(subset='User_ID')
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# ...         ...        ...    ...    ...         ...           ...
# 185450  1004588  P00260042      F  26-35           4             C
# 187076  1004871  P00242742      M  18-25          12             C
# 221494  1004113  P00351842      M  36-45          17             C
# 229480  1005391  P00339342      M  26-35           7             A
# 243533  1001529  P00000242      M  18-25           4             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.drop_duplicates(subset='User_ID',inplace=False)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# ...         ...        ...    ...    ...         ...           ...
# 185450  1004588  P00260042      F  26-35           4             C
# 187076  1004871  P00242742      M  18-25          12             C
# 221494  1004113  P00351842      M  36-45          17             C
# 229480  1005391  P00339342      M  26-35           7             A
# 243533  1001529  P00000242      M  18-25           4             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.drop_duplicates(subset='User_ID',inplace=True)
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# ...         ...        ...    ...    ...         ...           ...
# 185450  1004588  P00260042      F  26-35           4             C
# 187076  1004871  P00242742      M  18-25          12             C
# 221494  1004113  P00351842      M  36-45          17             C
# 229480  1005391  P00339342      M  26-35           7             A
# 243533  1001529  P00000242      M  18-25           4             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
import pandas as pd
file=pd.read_csv("C:/Users/deepika sakthivel/Documents/black_friday_train 1.csv")
df=pd.DataFrame(file)
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
#  12  Purchase.1                  550068 non-null  int64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
p0=df.Purchase.min()
p0
# Out:
# 12

# %%
p100=df.Purchase.max()
p100
# Out:
# 23961

# %%
q1=df.Purchase.quantile(0.25)
q2=df.Purchase.quantile(0.5)
q3=df.Purchase.quantile(0.75)
iqr=q3-q1
iqr
# Out:
# 6231.0

# %%
lower_cutoff=q1-1.5*iqr         # there are no outliers ----> if lowercut off<p0
lower_cutoff
# Out:
# -3523.5

# %%
upper_cutoff=q3+1.5*iqr          # there are no outliers------> if upper cut off >p100
upper_cutoff
# Out:
# 21400.5

# %%
print("p0=",p0,"p100=",p100,"lc=",lower_cutoff,"uc=",upper_cutoff)
# Out:
# p0= 12 p100= 23961 lc= -3523.5 uc= 21400.5

# %%
import matplotlib.pyplot as pd
df["Purchase"].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.boxplot(x=df["Purchase"])
# Out:
# <AxesSubplot:xlabel='Purchase'>

# %%
df.Purchase.clip(upper=upper_cutoff)
# Out:
# 0          8370.0
# 1         15200.0
# 2          1422.0
# 3          1057.0
# 4          7969.0
#            ...
# 550063      368.0
# 550064      371.0
# 550065      137.0
# 550066      365.0
# 550067      490.0
# Name: Purchase, Length: 550068, dtype: float64

# %%
df.Purchase.clip(lower=lower_cutoff)
# Out:
# 0          8370
# 1         15200
# 2          1422
# 3          1057
# 4          7969
#           ...
# 550063      368
# 550064      371
# 550065      137
# 550066      365
# 550067      490
# Name: Purchase, Length: 550068, dtype: int64

# %%
df.Purchase.clip(upper=upper_cutoff,inplace=True)
df.Purchase.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.Purchase.clip(lower=lower_cutoff,inplace=True)
df.Purchase.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# Purchase.1                         0
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Product_Category_3            383247
# Product_Category_2            173638
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Purchase                           0
# Purchase.1                         0
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=True)
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Purchase                           0
# Purchase.1                         0
# Product_Category_2            173638
# Product_Category_3            383247
# dtype: int64

# %%
df.isna().sum()/df.shape[0]
# Out:
# User_ID                       0.000000
# Product_ID                    0.000000
# Gender                        0.000000
# Age                           0.000000
# Occupation                    0.000000
# City_Category                 0.000000
# Stay_In_Current_City_Years    0.000000
# Marital_Status                0.000000
# Product_Category_1            0.000000
# Product_Category_2            0.315666
# Product_Category_3            0.696727
# Purchase                      0.000000
# Purchase.1                    0.000000
# dtype: float64

# %%
df.Product_Category_2.mode() #no of repeated values
# Out:
# 0    8.0
# dtype: float64

# %%
df.Product_Category_2.mode()[0]
# Out:
# 8.0

# %%
df.Product_Category_2.fillna(df.Product_Category_2.mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          550068 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  float64
#  12  Purchase.1                  550068 non-null  int64
# ...

# %%
df.dropna(axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          550068 non-null  float64
#  10  Purchase                    550068 non-null  float64
#  11  Purchase.1                  550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Purchase                      0
# Purchase.1                    0
# dtype: int64

# %%
#univariant data analysis
import matplotlib.pyplot as plt
df.Purchase.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.Purchase.plot()
# Out:
# <AxesSubplot:>

# %%
df.Purchase.hist()
# Out:
# <AxesSubplot:>

# %%
df.Marital_Status.hist()
# Out:
# <AxesSubplot:>

# %%
plt.scatter(x=df["Marital_Status"],y=df["Purchase"])

# %%
df.corr()
# Out:
#                      User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.023971        0.020443            0.003825
# Occupation         -0.023971    1.000000        0.024280           -0.007618
# Marital_Status      0.020443    0.024280        1.000000            0.019888
# Product_Category_1  0.003825   -0.007618        0.019888            1.000000
# Product_Category_2  0.002065    0.001566        0.010260            0.279247
# Purchase            0.004608    0.020853       -0.000599           -0.347413
# Purchase.1          0.004716    0.020833       -0.000463           -0.343703
#
#                     Product_Category_2  Purchase  Purchase.1
# User_ID                       0.002065  0.004608    0.004716
# Occupation                    0.001566  0.020853    0.020833
# Marital_Status                0.010260 -0.000599   -0.000463
# Product_Category_1            0.279247 -0.347413   -0.343703
# ...

# %%
import seaborn as sns
sns.heatmap(df.select_dtypes(['float64','int64']).corr(),annot=True)
plt.show()

# %%
df.groupby('Occupation').Occupation.count().plot(kind='pie')
plt.show()
